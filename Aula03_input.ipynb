# %% [markdown]
# <a href="https://colab.research.google.com/github/kauagameplays1234-code/Aula03_input/blob/main/Aula03_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("digite o seu nome: ")
print ("o seu nome é: ",nome)
# Out:
# digite o seu nome: kauã
# o seu nome é:  kauã

# %% [markdown]
# atividade 01

# %%
valor1= int(input("digite o seu primeiro valor: "))
valor2 = int(input("digite o seu segundo valor: "))
resultado = valor1 + valor2


print ("seu resultado é : ", resultado)
# Out:
# digite o seu valor: 2
# digite o seu valor: 3
# seu resultado é :  5

# %% [markdown]
# atividade 02

# %%
valor1= int(input("digite o seu primeiro valor: "))
valor2 = int(input("digite o seu segundo valor: "))
resultado = valor1 - valor2


print ("seu resultado é : ", resultado)
# Out:
# digite o seu primeiro valor: 60
# digite o seu segundo valor: 30
# seu resultado é :  30

# %% [markdown]
# atividade 03

# %%
valor1 = int(input("digite o seu primeiro número: "))
valor2 = int (input("digite o seu segundo número: "))

soma = valor1 + valor2
subtracao = valor1 - valor2
multiplicacao = valor1 * valor2
divisao = valor1 / valor2

print("o resultado da soma é: ",soma)
print("o resultado da subtração é: ",subtracao)
print("o resultado da multiplicação é: ",multiplicacao)
print("o resultado da divisão é: ",divisao)
# Out:
# digite o seu primeiro número: 30
# digite o seu segundo número: 60
# o resultado da soma é:  90
# o resultado da subtração é:  -30
# o resultado da multiplicação é:  1800
# o resultado da divisão é:  0.5

# %% [markdown]
# atividade 04

# %%
nome = input("digite o seu nome: ")

print("olá",nome,"seja bem-vindo")
# Out:
# digite o seu nome: Kauã
# olá Kauã seja bem-vindo

# %% [markdown]
# testando conhecimento

# %%
nome = input("insira o seu nome: ")
sobrenome = input("insira seu sobrenome:")

print("Olá",nome,sobrenome, "Seja bem vindo !")

idade = int(input("insira a sua idade: "))

print("sua idade é: ",idade)
# Out:
# insira o seu nome: Kauã
# insira seu sobrenome:Borges
# Olá Kauã Borges Seja bem vindo !
# insira a sua idade: 18
# sua idade é:  18
